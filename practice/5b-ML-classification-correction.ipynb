# %% [markdown]
# # Data management
#
# ## Machine Learning - Classifications
#
# ## [Malka Guillot](https://malkaguillot.github.io/)
#
# ## HEC Liège | [ECON2306]()

# %%
import numpy as np
import pandas as pd
# import patsy

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, roc_auc_score, classification_report, accuracy_score, confusion_matrix 

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: toy example using a logistic regression

# %% [markdown]
# ### Load & visualise data

# %%
df=pd.read_csv("../data/beers.csv")
df.shape
# Out:
# (225, 5)

# %%
df.head()
# Out:
#    alcohol_content  bitterness  darkness  fruitiness  is_yummy
# 0         3.739295    0.422503  0.989463    0.215791         0
# 1         4.207849    0.841668  0.928626    0.380420         0
# 2         4.709494    0.322037  5.374682    0.145231         1
# 3         4.684743    0.434315  4.072805    0.191321         1
# 4         4.148710    0.570586  1.461568    0.260218         0

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.countplot(x='is_yummy', data=df)
_ = plt.title('# Yummy vs not yummy')
_ = plt.xlabel('Class (1==Yummy)')

# %% [markdown]
# #### Prepare data: split features and labels

# %%
# all columns up to the last one:
X = df.iloc[:, :-1]
# only the last column:
y = df.iloc[:, -1]

# %% [markdown]
# ### Splitting into Training and Test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %% [markdown]
# ### Model Building and Training

# %% [markdown]
# #### Creating the pipeline

# %% [markdown]
# Before we build the model,
# 1. we use the standard scaler function to scale the values into a common range.
# 2. Next, we create an instance of LogisticRegression() function for logistic regression.
#
# We are not passing any parameters to `LogisticRegression()` so it will assume default parameters. Some of the important parameters you should know are –
#
# - **penalty**:  It specifies the norm for the penalty
#   - Default = L2
#
# - **C**:  It is the inverse of regularization strength
#   - Default = 1.0
#
# - **solver**: It denotes the optimizer algorithm
#   - Default = ‘lbfgs’

# %% [markdown]
# We are making use of `Pipeline` to create the model to streamline standard scalar and model building.

# %%
scaler = StandardScaler()

lr = LogisticRegression(max_iter=10000, solver='lbfgs') #syntax if you wand to add hyperparameters

model1 = Pipeline([('standardize', scaler),
                    ('log_reg', lr)])
model1
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('log_reg', LogisticRegression(max_iter=10000))])

# %% [markdown]
# #### Fit our model to the training data

# %%
model1.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('log_reg', LogisticRegression(max_iter=10000))])

# %%
model1.get_params
# Out:
# <bound method Pipeline.get_params of Pipeline(steps=[('standardize', StandardScaler()),
#                 ('log_reg', LogisticRegression(max_iter=10000))])>

# %% [markdown]
# #### Predictions for the class and for the probabilities

# %%
y_train_hat = model1.predict(X_train) # predicting on the training set
y_train_hat[:10]
# Out:
# array([0, 0, 0, 1, 1, 0, 1, 0, 0, 0])

# %%
y_train_hat_probs = model1.predict_proba(X_train)[:,1] # probabilities of being in class 1

# %% [markdown]
# We can see that the model predicts $y_i=1$ when $p_i>0.5$:

# %%
temp= pd.DataFrame({'y_train_hat': y_train_hat, 'y_train_hat_probs': y_train_hat_probs})
temp.head(10)
# Out:
#    y_train_hat  y_train_hat_probs
# 0            0           0.063636
# 1            0           0.414138
# 2            0           0.000031
# 3            1           0.643636
# 4            1           0.955426
# 5            0           0.000047
# 6            1           0.962593
# 7            0           0.077018
# 8            0           0.003881
# 9            0           0.001481

# %%
temp['y_train_hat_probs'].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Performance on the training set

# %%
train_accuracy = accuracy_score(y_train, y_train_hat)*100
train_auc_roc = roc_auc_score(y_train, y_train_hat_probs)*100

print('Confusion matrix:\n', confusion_matrix(y_train, y_train_hat))
print('Training AUC: %.4f %%' % train_auc_roc)
print('Training accuracy: %.4f %%' % train_accuracy)
# Out:
# Confusion matrix:
#  [[78  8]
#  [ 5 89]]
# Training AUC: 98.1321 %
# Training accuracy: 92.7778 %

# %% [markdown]
# ### Test set
#
# <div class="alert alert-info">
# <h4> Your turn</h4>
# Following the computation on the train set, compute for the test set:
#
#     - the class & proba predictions
#     - the accuracy and AUC
# </div>

# %%
# Predictions on the test set
y_test_hat = model1.predict(X_test)
# Probabilities of being in class 1
y_test_hat_probs = model1.predict_proba(X_test)[:,1]

# Metrics
test_accuracy = accuracy_score(y_test, y_test_hat)*100
test_auc_roc = roc_auc_score(y_test, y_test_hat_probs)*100

print('Confusion matrix:\n', confusion_matrix(y_test, y_test_hat))
print('Testing AUC: %.4f %%' % test_auc_roc)
print('Testing accuracy: %.4f %%' % test_accuracy)
# Out:
# Confusion matrix:
#  [[20  0]
#  [ 4 21]]
# Testing AUC: 96.6000 %
# Testing accuracy: 91.1111 %

# %%
print(classification_report(y_test, y_test_hat, digits=6))
# Out:
#               precision    recall  f1-score   support
#
#            0   0.833333  1.000000  0.909091        20
#            1   1.000000  0.840000  0.913043        25
#
#     accuracy                       0.911111        45
#    macro avg   0.916667  0.920000  0.911067        45
# weighted avg   0.925926  0.911111  0.911287        45

# %% [markdown]
# ### Plot the ROC curve

# %%
from sklearn import metrics

fpr, tpr, threshold = metrics.roc_curve(y_test, y_test_hat_probs)
print("tresholds:",  len(threshold))
roc_auc = metrics.auc(fpr, tpr)
roc_auc
# Out:
# tresholds: 8
# np.float64(0.966)

# %%
# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# We can further try to improve this model performance by hyperparameter tuning by changing the value of C or choosing other solvers available in `LogisticRegression()`.

# %% [markdown]
# ## Part 2

# %% [markdown]
# The objective is to build a classifier for whether a firm is going to default.

# %% [markdown]
# ### Load & visualise data

# %%
data = pd.read_csv("../data/bisnode_firms_clean.csv")

# %%
#pip install summarytools

# %%
from summarytools import dfSummary
dfSummary(data, is_collapsible = True)
# Out:
# <button type="button" class = "st-collapsible",
#     id = "btn-6100" onclick = "coll_toggle_6100()">Show Summary - data</button>
#     <div class="st-content" id="cont-6100">
#       <style type="text/css">
# #T_bc8c8 thead>tr>th {
#   text-align: left;
# }
# #T_bc8c8_row0_col0, #T_bc8c8_row1_col0, #T_bc8c8_row2_col0, #T_bc8c8_row3_col0, #T_bc8c8_row4_col0, #T_bc8c8_row5_col0, #T_bc8c8_row6_col0, #T_bc8c8_row7_col0, #T_bc8c8_row8_col0, #T_bc8c8_row9_col0, #T_bc8c8_row10_col0, #T_bc8c8_row11_col0, #T_bc8c8_row12_col0, #T_bc8c8_row13_col0, #T_bc8c8_row14_col0, #T_bc8c8_row15_col0, #T_bc8c8_row16_col0, #T_bc8c8_row17_col0, #T_bc8c8_row18_col0, #T_bc8c8_row19_col0, #T_bc8c8_row20_col0, #T_bc8c8_row21_col0, #T_bc8c8_row22_col0, #T_bc8c8_row23_col0, #T_bc8c8_row24_col0, #T_bc8c8_row25_col0, #T_bc8c8_row26_col0, #T_bc8c8_row27_col0, #T_bc8c8_row28_col0, #T_bc8c8_row29_col0, #T_bc8c8_row30_col0, #T_bc8c8_row31_col0, #T_bc8c8_row32_col0, #T_bc8c8_row33_col0, #T_bc8c8_row34_col0, #T_bc8c8_row35_col0, #T_bc8c8_row36_col0, #T_bc8c8_row37_col0, #T_bc8c8_row38_col0, #T_bc8c8_row39_col0, #T_bc8c8_row40_col0, #T_bc8c8_row41_col0, #T_bc8c8_row42_col0, #T_bc8c8_row43_col0, #T_bc8c8_row44_col0, #T_bc8c8_row45_col0, #T_bc8c8_row46_col0, #T_bc8c8_row47_col0, #T_bc8c8_row48_col0, #T_bc8c8_row49_col0, #T_bc8c8_row50_col0, #T_bc8c8_row51_col0, #T_bc8c8_row52_col0, #T_bc8c8_row53_col0, #T_bc8c8_row54_col0, #T_bc8c8_row55_col0, #T_bc8c8_row56_col0, #T_bc8c8_row57_col0, #T_bc8c8_row58_col0, #T_bc8c8_row59_col0, #T_bc8c8_row60_col0, #T_bc8c8_row61_col0, #T_bc8c8_row62_col0, #T_bc8c8_row63_col0, #T_bc8c8_row64_col0, #T_bc8c8_row65_col0, #T_bc8c8_row66_col0, #T_bc8c8_row67_col0, #T_bc8c8_row68_col0, #T_bc8c8_row69_col0, #T_bc8c8_row70_col0, #T_bc8c8_row71_col0, #T_bc8c8_row72_col0, #T_bc8c8_row73_col0, #T_bc8c8_row74_col0, #T_bc8c8_row75_col0, #T_bc8c8_row76_col0, #T_bc8c8_row77_col0, #T_bc8c8_row78_col0, #T_bc8c8_row79_col0, #T_bc8c8_row80_col0, #T_bc8c8_row81_col0, #T_bc8c8_row82_col0, #T_bc8c8_row83_col0, #T_bc8c8_row84_col0, #T_bc8c8_row85_col0, #T_bc8c8_row86_col0, #T_bc8c8_row87_col0, #T_bc8c8_row88_col0, #T_bc8c8_row89_col0, #T_bc8c8_row90_col0, #T_bc8c8_row91_col0, #T_bc8c8_row92_col0, #T_bc8c8_row93_col0, #T_bc8c8_row94_col0, #T_bc8c8_row95_col0, #T_bc8c8_row96_col0, #T_bc8c8_row97_col0, #T_bc8c8_row98_col0, #T_bc8c8_row99_col0, #T_bc8c8_row100_col0, #T_bc8c8_row101_col0, #T_bc8c8_row102_col0, #T_bc8c8_row103_col0, #T_bc8c8_row104_col0, #T_bc8c8_row105_col0, #T_bc8c8_row106_col0, #T_bc8c8_row107_col0, #T_bc8c8_row108_col0, #T_bc8c8_row109_col0, #T_bc8c8_row110_col0, #T_bc8c8_row111_col0, #T_bc8c8_row112_col0, #T_bc8c8_row113_col0, #T_bc8c8_row114_col0, #T_bc8c8_row115_col0, #T_bc8c8_row116_col0, #T_bc8c8_row117_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_bc8c8_row0_col1, #T_bc8c8_row1_col1, #T_bc8c8_row2_col1, #T_bc8c8_row3_col1, #T_bc8c8_row4_col1, #T_bc8c8_row5_col1, #T_bc8c8_row6_col1, #T_bc8c8_row7_col1, #T_bc8c8_row8_col1, #T_bc8c8_row9_col1, #T_bc8c8_row10_col1, #T_bc8c8_row11_col1, #T_bc8c8_row12_col1, #T_bc8c8_row13_col1, #T_bc8c8_row14_col1, #T_bc8c8_row15_col1, #T_bc8c8_row16_col1, #T_bc8c8_row17_col1, #T_bc8c8_row18_col1, #T_bc8c8_row19_col1, #T_bc8c8_row20_col1, #T_bc8c8_row21_col1, #T_bc8c8_row22_col1, #T_bc8c8_row23_col1, #T_bc8c8_row24_col1, #T_bc8c8_row25_col1, #T_bc8c8_row26_col1, #T_bc8c8_row27_col1, #T_bc8c8_row28_col1, #T_bc8c8_row29_col1, #T_bc8c8_row30_col1, #T_bc8c8_row31_col1, #T_bc8c8_row32_col1, #T_bc8c8_row33_col1, #T_bc8c8_row34_col1, #T_bc8c8_row35_col1, #T_bc8c8_row36_col1, #T_bc8c8_row37_col1, #T_bc8c8_row38_col1, #T_bc8c8_row39_col1, #T_bc8c8_row40_col1, #T_bc8c8_row41_col1, #T_bc8c8_row42_col1, #T_bc8c8_row43_col1, #T_bc8c8_row44_col1, #T_bc8c8_row45_col1, #T_bc8c8_row46_col1, #T_bc8c8_row47_col1, #T_bc8c8_row48_col1, #T_bc8c8_row49_col1, #T_bc8c8_row50_col1, #T_bc8c8_row51_col1, #T_bc8c8_row52_col1, #T_bc8c8_row53_col1, #T_bc8c8_row54_col1, #T_bc8c8_row55_col1, #T_bc8c8_row56_col1, #T_bc8c8_row57_col1, #T_bc8c8_row58_col1, #T_bc8c8_row59_col1, #T_bc8c8_row60_col1, #T_bc8c8_row61_col1, #T_bc8c8_row62_col1, #T_bc8c8_row63_col1, #T_bc8c8_row64_col1, #T_bc8c8_row65_col1, #T_bc8c8_row66_col1, #T_bc8c8_row67_col1, #T_bc8c8_row68_col1, #T_bc8c8_row69_col1, #T_bc8c8_row70_col1, #T_bc8c8_row71_col1, #T_bc8c8_row72_col1, #T_bc8c8_row73_col1, #T_bc8c8_row74_col1, #T_bc8c8_row75_col1, #T_bc8c8_row76_col1, #T_bc8c8_row77_col1, #T_bc8c8_row78_col1, #T_bc8c8_row79_col1, #T_bc8c8_row80_col1, #T_bc8c8_row81_col1, #T_bc8c8_row82_col1, #T_bc8c8_row83_col1, #T_bc8c8_row84_col1, #T_bc8c8_row85_col1, #T_bc8c8_row86_col1, #T_bc8c8_row87_col1, #T_bc8c8_row88_col1, #T_bc8c8_row89_col1, #T_bc8c8_row90_col1, #T_bc8c8_row91_col1, #T_bc8c8_row92_col1, #T_bc8c8_row93_col1, #T_bc8c8_row94_col1, #T_bc8c8_row95_col1, #T_bc8c8_row96_col1, #T_bc8c8_row97_col1, #T_bc8c8_row98_col1, #T_bc8c8_row99_col1, #T_bc8c8_row100_col1, #T_bc8c8_row101_col1, #T_bc8c8_row102_col1, #T_bc8c8_row103_col1, #T_bc8c8_row104_col1, #T_bc8c8_row105_col1, #T_bc8c8_row106_col1, #T_bc8c8_row107_col1, #T_bc8c8_row108_col1, #T_bc8c8_row109_col1, #T_bc8c8_row110_col1, #T_bc8c8_row111_col1, #T_bc8c8_row112_col1, #T_bc8c8_row113_col1, #T_bc8c8_row114_col1, #T_bc8c8_row115_col1, #T_bc8c8_row116_col1, #T_bc8c8_row117_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_bc8c8_row0_col2, #T_bc8c8_row1_col2, #T_bc8c8_row2_col2, #T_bc8c8_row3_col2, #T_bc8c8_row4_col2, #T_bc8c8_row5_col2, #T_bc8c8_row6_col2, #T_bc8c8_row7_col2, #T_bc8c8_row8_col2, #T_bc8c8_row9_col2, #T_bc8c8_row10_col2, #T_bc8c8_row11_col2, #T_bc8c8_row12_col2, #T_bc8c8_row13_col2, #T_bc8c8_row14_col2, #T_bc8c8_row15_col2, #T_bc8c8_row16_col2, #T_bc8c8_row17_col2, #T_bc8c8_row18_col2, #T_bc8c8_row19_col2, #T_bc8c8_row20_col2, #T_bc8c8_row21_col2, #T_bc8c8_row22_col2, #T_bc8c8_row23_col2, #T_bc8c8_row24_col2, #T_bc8c8_row25_col2, #T_bc8c8_row26_col2, #T_bc8c8_row27_col2, #T_bc8c8_row28_col2, #T_bc8c8_row29_col2, #T_bc8c8_row30_col2, #T_bc8c8_row31_col2, #T_bc8c8_row32_col2, #T_bc8c8_row33_col2, #T_bc8c8_row34_col2, #T_bc8c8_row35_col2, #T_bc8c8_row36_col2, #T_bc8c8_row37_col2, #T_bc8c8_row38_col2, #T_bc8c8_row39_col2, #T_bc8c8_row40_col2, #T_bc8c8_row41_col2, #T_bc8c8_row42_col2, #T_bc8c8_row43_col2, #T_bc8c8_row44_col2, #T_bc8c8_row45_col2, #T_bc8c8_row46_col2, #T_bc8c8_row47_col2, #T_bc8c8_row48_col2, #T_bc8c8_row49_col2, #T_bc8c8_row50_col2, #T_bc8c8_row51_col2, #T_bc8c8_row52_col2, #T_bc8c8_row53_col2, #T_bc8c8_row54_col2, #T_bc8c8_row55_col2, #T_bc8c8_row56_col2, #T_bc8c8_row57_col2, #T_bc8c8_row58_col2, #T_bc8c8_row59_col2, #T_bc8c8_row60_col2, #T_bc8c8_row61_col2, #T_bc8c8_row62_col2, #T_bc8c8_row63_col2, #T_bc8c8_row64_col2, #T_bc8c8_row65_col2, #T_bc8c8_row66_col2, #T_bc8c8_row67_col2, #T_bc8c8_row68_col2, #T_bc8c8_row69_col2, #T_bc8c8_row70_col2, #T_bc8c8_row71_col2, #T_bc8c8_row72_col2, #T_bc8c8_row73_col2, #T_bc8c8_row74_col2, #T_bc8c8_row75_col2, #T_bc8c8_row76_col2, #T_bc8c8_row77_col2, #T_bc8c8_row78_col2, #T_bc8c8_row79_col2, #T_bc8c8_row80_col2, #T_bc8c8_row81_col2, #T_bc8c8_row82_col2, #T_bc8c8_row83_col2, #T_bc8c8_row84_col2, #T_bc8c8_row85_col2, #T_bc8c8_row86_col2, #T_bc8c8_row87_col2, #T_bc8c8_row88_col2, #T_bc8c8_row89_col2, #T_bc8c8_row90_col2, #T_bc8c8_row91_col2, #T_bc8c8_row92_col2, #T_bc8c8_row93_col2, #T_bc8c8_row94_col2, #T_bc8c8_row95_col2, #T_bc8c8_row96_col2, #T_bc8c8_row97_col2, #T_bc8c8_row98_col2, #T_bc8c8_row99_col2, #T_bc8c8_row100_col2, #T_bc8c8_row101_col2, #T_bc8c8_row102_col2, #T_bc8c8_row103_col2, #T_bc8c8_row104_col2, #T_bc8c8_row105_col2, #T_bc8c8_row106_col2, #T_bc8c8_row107_col2, #T_bc8c8_row108_col2, #T_bc8c8_row109_col2, #T_bc8c8_row110_col2, #T_bc8c8_row111_col2, #T_bc8c8_row112_col2, #T_bc8c8_row113_col2, #T_bc8c8_row114_col2, #T_bc8c8_row115_col2, #T_bc8c8_row116_col2, #T_bc8c8_row117_col2 {
#   text-align: left;
#   font

# %%
sns.set_theme()
sns.histplot(data=data, x="default_f", stat="percent") 
plt.title('Default frequency')
plt.xlabel('Default frequency') 
plt.show()

# %%
y=data['default']
X=data.drop(columns='default')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# All sets are balanced:

# %%
print("--- Total ---")
print(y.value_counts(normalize=True))
print("--- Train ---")
print(y_train.value_counts(normalize=True))
print("--- Test ---")
print(y_test.value_counts(normalize=True))
# Out:
# --- Total ---
# default
# 0    0.797857
# 1    0.202143
# Name: proportion, dtype: float64
# --- Train ---
# default
# 0    0.799958
# 1    0.200042
# Name: proportion, dtype: float64
# --- Test ---
# default
# 0    0.791553
# 1    0.208447
# Name: proportion, dtype: float64

# %% [markdown]
# ### Model building
#
# There are so many variables !
#
# We are going to compare several models :
# - Logit with a selection of variables **M1**
# - Logit with a selection of variables **M2**
# - Regularized logit on **M2** variables

# %% [markdown]
# Firm related variables

# %%
firm = ["age", "age2", "new", "ind2_cat", "m_region_loc", "urban_m"]

# %% [markdown]
# Human capital related variables

# %%
hr = [
    "female",
    "ceo_age",
    "flag_high_ceo_age",
    "flag_low_ceo_age",
    "flag_miss_ceo_age",
    "ceo_count",
    "labor_avg_mod",
    "flag_miss_labor_avg",
    "foreign_management",
]

# %% [markdown]
# Financial variables

# %%
qualityvars = ["balsheet_flag", "balsheet_length", "balsheet_notfullyear"]

engvar = [
    "total_assets_bs",
    "fixed_assets_bs",
    "liq_assets_bs",
    "curr_assets_bs",
    "share_eq_bs",
    "subscribed_cap_bs",
    "intang_assets_bs",
    "extra_exp_pl",
    "extra_inc_pl",
    "extra_profit_loss_pl",
    "inc_bef_tax_pl",
    "inventories_pl",
    "material_exp_pl",
    "profit_loss_year_pl",
    "personnel_exp_pl",
]

# %% [markdown]
# Growth variables

# %%
d1 = [ 
    "d1_sales_mil_log_mod",
    "d1_sales_mil_log_mod_sq",
    "flag_low_d1_sales_mil_log",
    "flag_high_d1_sales_mil_log",
]

# %%
M1 = [
    "sales_mil_log",
    "sales_mil_log_sq",
    "d1_sales_mil_log_mod",
    "profit_loss_year_pl",
    "fixed_assets_bs",
    "share_eq_bs",
    "age",
    "foreign_management",
    "ind2_cat",
]
M2 = ["sales_mil_log", "sales_mil_log_sq"] + firm + engvar + d1 + hr

# %% [markdown]
# #### Selection of the relevant variables

# %%
# M1
X_train_M1=X_train[M1]
X_test_M1 =X_test[M1]

# %%
# M2
X_train_M2=X_train[M2]
X_test_M2 =X_test[M2]

# %% [markdown]
# #### Set up the method for model selection

# %%
k = KFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# #### No regularisation needed so setting the paremeter to very high value

# %%
C_value_logit = [1e20]

# %% [markdown]
# #### Where we put the results of the different models, for comparison purposes:

# %%
test_accuracy={}
test_auc_roc={}

# %% [markdown]
# ### Model 1: Logit
# #### Set up Logit model object

# %%
logistic = LogisticRegressionCV(
    Cs=C_value_logit,   #  # Cs: inverse of regularization strength.
    cv=k,               # 5-fold cross-validation
    refit=True,         # Refit the best estimator with the entire dataset
    solver="newton-cg", # Optimization algorithm
    tol=1e-7,           # Tolerance for stopping criteria
    random_state=42,    # Random seed
)

# %% [markdown]
# #### Creating the pipeline

# %%
pipeline_logit = Pipeline([
    ('standardize', StandardScaler()),
    ('log_reg', logistic)
                          ])
pipeline_logit
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('log_reg',
#                  LogisticRegressionCV(Cs=[1e+20],
#                                       cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                                       random_state=42, solver='newton-cg',
#                                       tol=1e-07))])

# %% [markdown]
# #### On M1 features set

# %%
pipeline_logit.fit(X_train_M1, y_train)
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('log_reg',
#                  LogisticRegressionCV(Cs=[1e+20],
#                                       cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                                       random_state=42, solver='newton-cg',
#                                       tol=1e-07))])

# %%
# Predictions on the test set
y_test_hat = pipeline_logit.predict(X_test_M1)
y_test_hat_probs = pipeline_logit.predict_proba(X_test_M1)[:,1]

# Metrics
test_accuracy['logit_m1'] = accuracy_score(y_test, y_test_hat)*100
test_auc_roc['logit_m1'] = roc_auc_score(y_test, y_test_hat_probs)*100

print('Confusion matrix:\n', confusion_matrix(y_test, y_test_hat))
print('Testing AUC: %.4f %%' % test_auc_roc['logit_m1'])
print('Testing accuracy: %.4f %%' % test_accuracy['logit_m1'])
# Out:
# Confusion matrix:
#  [[3615  152]
#  [ 786  206]]
# Testing AUC: 76.5941 %
# Testing accuracy: 80.2900 %

# %% [markdown]
# #### On M2 features set

# %% [markdown]
# We need to deal with all the features: depending on their type, the pre-processing will be different

# %% [markdown]
# ##### Categorical features

# %%
from sklearn.compose import make_column_selector as selector 

categorical_columns_selector = selector(dtype_include=object)  # Selects all columns of type object
categorical_features = categorical_columns_selector(X_train_M2) # Apply the selector to the training set
categorical_features
# Out:
# ['m_region_loc']

# %%
categorical_transformer = Pipeline(
    steps=[
        ("encoder", OneHotEncoder(handle_unknown="ignore")),
    ]
)
categorical_transformer
# Out:
# Pipeline(steps=[('encoder', OneHotEncoder(handle_unknown='ignore'))])

# %% [markdown]
# ##### Numeric features

# %%
numeric_features = [col for col in X_train_M2.columns if col not in categorical_features] # Select the columns that are not categorical
len(numeric_features)
# Out:
# 35

# %%
numeric_transformer = Pipeline(
    steps=[("scaler", StandardScaler())]
)
numeric_transformer
# Out:
# Pipeline(steps=[('scaler', StandardScaler())])

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scaler', StandardScaler())]),
#                                  ['sales_mil_log', 'sales_mil_log_sq', 'age',
#                                   'age2', 'new', 'ind2_cat', 'urban_m',
#                                   'total_assets_bs', 'fixed_assets_bs',
#                                   'liq_assets_bs', 'curr_assets_bs',
#                                   'share_eq_bs', 'subscribed_cap_bs',
#                                   'intang_assets_bs', 'extra_exp_pl',
#                                   'extra_inc_pl', 'extra_profit_loss_pl',
#                                   'inc_bef_tax_pl', 'inventories_pl',
#                                   'material_exp_pl', 'profit_loss_year_pl',
#                                   'personnel_exp_pl', 'd1_sales_mil_log_mod',
#                                   'd1_sales_mil_log_mod_sq',
#                                   'flag_low_d1_sales_mil_log',
#                                   'flag_high_d1_sales_mil_log', 'female',
#                                   'ceo_age', 'flag_high_ceo_age',
#                                   'flag_low_ceo_age', ...]),
#                                 ('cat',
#                                  Pipeline(steps=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['m_region_loc'])])

# %% [markdown]
# ##### The pipeline:

# %%
#Append classifier to preprocessing pipeline. Now we have a full prediction pipeline.
pipeline_logit = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", logistic)]
)
pipeline_logit
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sales_mil_log',
#                                                    'sales_mil_log_sq', 'age',
#                                                    'age2', 'new', 'ind2_cat',
#                                                    'urban_m', 'total_assets_bs',
#                                                    'fixed_assets_bs',
#                                                    'liq_assets_bs',
#                                                    'curr_assets_bs',
#                                                    'share_eq_bs',
#                                                    'subscribed_cap_bs',
#                                                    'intang_assets_bs',
#                                                    'extra_exp_pl',
#                                                    'extra_inc_pl',
#                                                    'extr...
#                                                    'flag_low_d1_sales_mil_log',
#                                                    'flag_high_d1_sales_mil_log',
#                                                    'female', 'ceo_age',
#                                                    'flag_high_ceo_age',
#                                                    'flag_low_ceo_age', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['m_region_loc'])])),
#                 ('classifier',
#                  LogisticRegressionCV(Cs=[1e+20],
#                                       cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                                       random_state=42, solver='newton-cg',
#                                       tol=1e-07))])

# %% [markdown]
# <div class="alert alert-info">
# <h4> Your turn: Fit the pipeline </h4>
# Following M1 example, estimate and evaluate a logit model with cross-validation using the M2 set of features.
# </div>

# %%
pipeline_logit.fit(X_train_M2, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sales_mil_log',
#                                                    'sales_mil_log_sq', 'age',
#                                                    'age2', 'new', 'ind2_cat',
#                                                    'urban_m', 'total_assets_bs',
#                                                    'fixed_assets_bs',
#                                                    'liq_assets_bs',
#                                                    'curr_assets_bs',
#                                                    'share_eq_bs',
#                                                    'subscribed_cap_bs',
#                                                    'intang_assets_bs',
#                                                    'extra_exp_pl',
#                                                    'extra_inc_pl',
#                                                    'extr...
#                                                    'flag_low_d1_sales_mil_log',
#                                                    'flag_high_d1_sales_mil_log',
#                                                    'female', 'ceo_age',
#                                                    'flag_high_ceo_age',
#                                                    'flag_low_ceo_age', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['m_region_loc'])])),
#                 ('classifier',
#                  LogisticRegressionCV(Cs=[1e+20],
#                                       cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                                       random_state=42, solver='newton-cg',
#                                       tol=1e-07))])

# %% [markdown]
# ##### Performances for M2

# %%
y_test_hat = pipeline_logit.predict(X_test_M2) # predicting on the test set
y_test_hat_probs = pipeline_logit.predict_proba(X_test_M2)[:,1] # probabilities of being in class 1

test_accuracy['logit_m2'] = accuracy_score(y_test, y_test_hat)*100
test_auc_roc['logit_m2'] = roc_auc_score(y_test, y_test_hat_probs)*100

print('Confusion matrix:\n', confusion_matrix(y_test, y_test_hat))
print('Testing AUC: %.4f %%' % test_auc_roc['logit_m2'])
print('Testing accuracy: %.4f %%' % test_accuracy['logit_m2'])
# Out:
# Confusion matrix:
#  [[3606  161]
#  [ 745  247]]
# Testing AUC: 77.8797 %
# Testing accuracy: 80.9624 %

# %% [markdown]
# #### Comparing performance for the 2 logit models:

# %%
test_auc_roc
# Out:
# {'logit_m1': np.float64(76.59411742038243),
#  'logit_m2': np.float64(77.87974087363095)}

# %%
test_accuracy
# Out:
# {'logit_m1': 80.28997688590039, 'logit_m2': 80.96238705610422}

# %% [markdown]
# ### Model 2: Lasso with standardized X data

# %%
lambdas = list(10 ** np.arange(-1, -4.01, -1 / 3)) # 10^-1, 10^-0.67, 10^-0.33, 10^0, 10^0.33, 10^0.67, 10^1
n_obs = X_train_M2.shape[0] * 4 / 5 # 4/5 of the training set
C_values = [
    1 / (l * n_obs) for l in lambdas
]  # Cs are the inverse of regularization strength
len(C_values)
# Out:
# 10

# %%
logistic_lasso = LogisticRegressionCV(
    Cs=C_values,
    penalty="l1", # L1 regularization = lasso 
    cv=k,
    refit=True,
    scoring="roc_auc",
    solver="liblinear",
    random_state=42,
)

# %% [markdown]
# <div class="alert alert-info">
# <h4> Your turn: Create and implement the pipeline with the logistic lasso </h4>
# </div>

# %%
#Append classifier to preprocessing pipeline. Now we have a full prediction pipeline.
pipeline_logistic_lasso = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", logistic_lasso)]
)
pipeline_logistic_lasso
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sales_mil_log',
#                                                    'sales_mil_log_sq', 'age',
#                                                    'age2', 'new', 'ind2_cat',
#                                                    'urban_m', 'total_assets_bs',
#                                                    'fixed_assets_bs',
#                                                    'liq_assets_bs',
#                                                    'curr_assets_bs',
#                                                    'share_eq_bs',
#                                                    'subscribed_cap_bs',
#                                                    'intang_assets_bs',
#                                                    'extra_exp_pl',
#                                                    'extra_inc_pl',
#                                                    'extr...
#                                           np.float64(0.004063869189616846),
#                                           np.float64(0.00875534075786229),
#                                           np.float64(0.018862809851788558),
#                                           np.float64(0.04063869189616842),
#                                           np.float64(0.08755340757862287),
#                                           np.float64(0.1886280985178856),
#                                           np.float64(0.4063869189616842),
#                                           np.float64(0.8755340757862277)],
#                                       cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                                       penalty='l1', random_state=42,
#                                       scoring='roc_auc', solver='liblinear'))])

# %%
logLasso=pipeline_logistic_lasso.fit(X_train_M2, y_train)
logLasso
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sales_mil_log',
#                                                    'sales_mil_log_sq', 'age',
#                                                    'age2', 'new', 'ind2_cat',
#                                                    'urban_m', 'total_assets_bs',
#                                                    'fixed_assets_bs',
#                                                    'liq_assets_bs',
#                                                    'curr_assets_bs',
#                                                    'share_eq_bs',
#                                                    'subscribed_cap_bs',
#                                                    'intang_assets_bs',
#                                                    'extra_exp_pl',
#                                                    'extra_inc_pl',
#                                                    'extr...
#                                           np.float64(0.004063869189616846),
#                                           np.float64(0.00875534075786229),
#                                           np.float64(0.018862809851788558),
#                                           np.float64(0.04063869189616842),
#                                           np.float64(0.08755340757862287),
#                                           np.float64(0.1886280985178856),
#                                           np.float64(0.4063869189616842),
#                                           np.float64(0.8755340757862277)],
#                                       cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                                       penalty='l1', random_state=42,
#                                       scoring='roc_auc', solver='liblinear'))])

# %%
from sklearn.model_selection import cross_val_score

# %%
# k = KFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(pipeline_logistic_lasso, X_train_M2, y_train, cv = k)

# %%
y_test_hat = pipeline_logistic_lasso.predict(X_test_M2)
y_test_hat_probs = pipeline_logistic_lasso.predict_proba(X_test_M2)[:,1]

# %%
test_accuracy['logistic_lasso'] = accuracy_score(y_test, y_test_hat)*100
test_auc_roc['logistic_lasso'] = roc_auc_score(y_test, y_test_hat_probs)*100

# %%
from sklearn import metrics

fpr, tpr, threshold = metrics.roc_curve(y_test, y_test_hat_probs)
roc_auc = metrics.auc(fpr, tpr)
threshold
# Out:
# array([       inf, 0.92899416, 0.86952718, ..., 0.01826181, 0.01825688,
#        0.01127071])

# %%
# method I: plt
import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ### Comparing the models

# %%
test_auc_roc
# Out:
# {'logit_m1': np.float64(76.59411742038243),
#  'logit_m2': np.float64(77.87974087363095),
#  'logistic_lasso': np.float64(77.82742427875353)}

# %%
test_accuracy
# Out:
# {'logit_m1': 80.28997688590039,
#  'logit_m2': 80.96238705610422,
#  'logistic_lasso': 80.75225887791552}

# %% [markdown]
# #### Deciding on the model

# %% [markdown]
# `logit_m2` seems to perform marginaly better on the test set.

# %% [markdown]
# ### Re-estimating the model on the full dataset

# %%
#Append classifier to preprocessing pipeline. Now we have a full prediction pipeline.
pipeline_logit = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", logistic)]
)
pipeline_logit
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sales_mil_log',
#                                                    'sales_mil_log_sq', 'age',
#                                                    'age2', 'new', 'ind2_cat',
#                                                    'urban_m', 'total_assets_bs',
#                                                    'fixed_assets_bs',
#                                                    'liq_assets_bs',
#                                                    'curr_assets_bs',
#                                                    'share_eq_bs',
#                                                    'subscribed_cap_bs',
#                                                    'intang_assets_bs',
#                                                    'extra_exp_pl',
#                                                    'extra_inc_pl',
#                                                    'extr...
#                                                    'flag_low_d1_sales_mil_log',
#                                                    'flag_high_d1_sales_mil_log',
#                                                    'female', 'ceo_age',
#                                                    'flag_high_ceo_age',
#                                                    'flag_low_ceo_age', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['m_region_loc'])])),
#                 ('classifier',
#                  LogisticRegressionCV(Cs=[1e+20],
#                                       cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                                       random_state=42, solver='newton-cg',
#                                       tol=1e-07))])

# %%
X_M2 = X[M2]

# %%
logLasso=pipeline_logit.fit(X_M2, y)
logLasso
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sales_mil_log',
#                                                    'sales_mil_log_sq', 'age',
#                                                    'age2', 'new', 'ind2_cat',
#                                                    'urban_m', 'total_assets_bs',
#                                                    'fixed_assets_bs',
#                                                    'liq_assets_bs',
#                                                    'curr_assets_bs',
#                                                    'share_eq_bs',
#                                                    'subscribed_cap_bs',
#                                                    'intang_assets_bs',
#                                                    'extra_exp_pl',
#                                                    'extra_inc_pl',
#                                                    'extr...
#                                                    'flag_low_d1_sales_mil_log',
#                                                    'flag_high_d1_sales_mil_log',
#                                                    'female', 'ceo_age',
#                                                    'flag_high_ceo_age',
#                                                    'flag_low_ceo_age', ...]),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['m_region_loc'])])),
#                 ('classifier',
#                  LogisticRegressionCV(Cs=[1e+20],
#                                       cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                                       random_state=42, solver='newton-cg',
#                                       tol=1e-07))])

# %% [markdown]
# ### Using the model

# %%
#y_new_hat = logLasso.predict(X_new)

# %% [markdown]
# ## Going further

# %%
# pip install xgboost

# %% [markdown]
# Let's look at one of the most powerful machine learning model: `xgboost` (cf. [documentation](https://xgboost.readthedocs.io/en/latest/index.html))

# %%
import xgboost as xgb

# %%
xgb_model = xgb.XGBClassifier(objective="reg:squarederror", random_state=42)

# %%
#Append classifier to preprocessing pipeline. Now we have a full prediction pipeline.
pipeline_xgp = Pipeline(
    steps=[("preprocessor", preprocessor), ("classifier", xgb_model)]
)
pipeline_xgp
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sales_mil_log',
#                                                    'sales_mil_log_sq', 'age',
#                                                    'age2', 'new', 'ind2_cat',
#                                                    'urban_m', 'total_assets_bs',
#                                                    'fixed_assets_bs',
#                                                    'liq_assets_bs',
#                                                    'curr_assets_bs',
#                                                    'share_eq_bs',
#                                                    'subscribed_cap_bs',
#                                                    'intang_assets_bs',
#                                                    'extra_exp_pl',
#                                                    'extra_inc_pl',
#                                                    'extr...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='reg:squarederror', ...))])

# %%
model_xgb=pipeline_xgp.fit(X_train_M2, y_train)
model_xgb
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['sales_mil_log',
#                                                    'sales_mil_log_sq', 'age',
#                                                    'age2', 'new', 'ind2_cat',
#                                                    'urban_m', 'total_assets_bs',
#                                                    'fixed_assets_bs',
#                                                    'liq_assets_bs',
#                                                    'curr_assets_bs',
#                                                    'share_eq_bs',
#                                                    'subscribed_cap_bs',
#                                                    'intang_assets_bs',
#                                                    'extra_exp_pl',
#                                                    'extra_inc_pl',
#                                                    'extr...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None,
#                                objective='reg:squarederror', ...))])

# %%
y_test_hat = model_xgb.predict(X_test_M2)
y_test_hat_probs = model_xgb.predict_proba(X_test_M2)[:,1]

# %%
test_accuracy['xgb'] = accuracy_score(y_test, y_test_hat)*100
test_auc_roc['xgb'] = roc_auc_score(y_test, y_test_hat_probs)*100

# %%
test_accuracy
# Out:
# {'logit_m1': 80.28997688590039,
#  'logit_m2': 80.96238705610422,
#  'logistic_lasso': 80.75225887791552,
#  'xgb': 80.98339987392309}
